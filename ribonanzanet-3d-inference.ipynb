# %% [markdown]
# ## Step 1 : Imports

# %%
import pandas as pd
import torch
import matplotlib.pyplot as plt
import numpy as np
import torch
import random
import pickle
from tqdm import tqdm

# %% [markdown]
# ## Step 2: Configs

# %%
config = {
    "seed": 0,
    "cutoff_date": "2020-01-01",
    "test_cutoff_date": "2022-05-01",
    "max_len": 384,
    "batch_size": 1,
    "learning_rate": 1e-4,
    "weight_decay": 0.0,
    "mixed_precision": "bf16",
    "model_config_path": "../working/configs/pairwise.yaml",  # Adjust path as needed
    "epochs": 10,
    "cos_epoch": 5,
    "loss_power_scale": 1.0,
    "max_cycles": 1,
    "grad_clip": 0.1,
    "gradient_accumulation_steps": 1,
    "d_clamp": 30,
    "max_len_filter": 9999999,
    "structural_violation_epoch": 50,
    "balance_weight": False,
}

# %% [markdown]
# ## Step 3: Load data

# %%
train_sequences = pd.read_csv("/kaggle/input/stanford-ribonanza-2-rna-folding-in-3-d/train_sequences.csv")
train_labels = pd.read_csv("/kaggle/input/stanford-ribonanza-2-rna-folding-in-3-d/train_labels.csv")

train_sequences.columns, train_labels.columns
# Out:
# (Index(['target_id', 'sequence', 'temporal_cutoff', 'description',
#         'all_sequences'],
#        dtype='object'),
#  Index(['ID', 'resname', 'resid', 'x_1', 'y_1', 'z_1'], dtype='object'))

# %%
train_labels["pdb_id"] = train_labels["ID"].apply(lambda x: x.split("_")[0]+'_'+x.split("_")[1])
train_labels["pdb_id"]
# Out:
# 0         1SCL_A
# 1         1SCL_A
# 2         1SCL_A
# 3         1SCL_A
# 4         1SCL_A
#            ...
# 137090    8Z1F_T
# 137091    8Z1F_T
# 137092    8Z1F_T
# 137093    8Z1F_T
# 137094    8Z1F_T
# Name: pdb_id, Length: 137095, dtype: object

# %%
all_xyz=[]

for pdb_id in tqdm(train_sequences['target_id']):
    df = train_labels[train_labels["pdb_id"]==pdb_id]
    xyz=df[['x_1','y_1','z_1']].to_numpy().astype('float32')
    xyz[xyz<-1e17]=float('Nan');
    all_xyz.append(xyz)
# Out:
#   1%|          | 10/844 [00:00<00:08, 97.44it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#   4%|▍         | 32/844 [00:00<00:07, 105.83it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#   8%|▊         | 65/844 [00:00<00:07, 106.76it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#   9%|▉         | 76/844 [00:00<00:07, 106.78it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  12%|█▏        | 98/844 [00:00<00:06, 107.24it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  14%|█▍        | 120/844 [00:01<00:06, 106.41it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  16%|█▌        | 131/844 [00:01<00:06, 105.87it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  17%|█▋        | 142/844 [00:01<00:06, 105.91it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  18%|█▊        | 153/844 [00:01<00:06, 105.57it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  19%|█▉        | 164/844 [00:01<00:06, 105.69it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  21%|██        | 175/844 [00:01<00:06, 105.83it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  22%|██▏       | 186/844 [00:01<00:06, 105.61it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  23%|██▎       | 197/844 [00:01<00:06, 105.03it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  25%|██▍       | 208/844 [00:01<00:06, 105.06it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  26%|██▌       | 219/844 [00:02<00:06, 103.75it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  27%|██▋       | 230/844 [00:02<00:05, 102.92it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  29%|██▊       | 241/844 [00:02<00:05, 103.45it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  30%|██▉       | 252/844 [00:02<00:05, 103.91it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  31%|███       | 263/844 [00:02<00:05, 103.80it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  32%|███▏      | 274/844 [00:02<00:05, 103.30it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  35%|███▌      | 296/844 [00:02<00:05, 103.71it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  36%|███▋      | 307/844 [00:02<00:05, 103.34it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  40%|████      | 340/844 [00:03<00:04, 104.21it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  42%|████▏     | 351/844 [00:03<00:04, 104.77it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  43%|████▎     | 362/844 [00:03<00:04, 105.40it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  44%|████▍     | 373/844 [00:03<00:04, 105.01it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  45%|████▌     | 384/844 [00:03<00:04, 104.29it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  47%|████▋     | 395/844 [00:03<00:04, 104.12it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  49%|████▉     | 417/844 [00:03<00:04, 105.93it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  51%|█████     | 428/844 [00:04<00:03, 105.63it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  52%|█████▏    | 439/844 [00:04<00:03, 106.10it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  53%|█████▎    | 450/844 [00:04<00:03, 104.82it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  55%|█████▍    | 461/844 [00:04<00:03, 104.65it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  56%|█████▌    | 472/844 [00:04<00:03, 105.28it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  57%|█████▋    | 483/844 [00:04<00:03, 105.07it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  59%|█████▊    | 494/844 [00:04<00:03, 104.85it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  60%|█████▉    | 505/844 [00:04<00:03, 104.16it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  61%|██████    | 516/844 [00:04<00:03, 103.57it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  62%|██████▏   | 527/844 [00:05<00:03, 103.79it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  64%|██████▎   | 538/844 [00:05<00:02, 104.40it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  65%|██████▌   | 549/844 [00:05<00:02, 105.11it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  66%|██████▋   | 560/844 [00:05<00:02, 105.57it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  68%|██████▊   | 571/844 [00:05<00:02, 105.96it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  69%|██████▉   | 582/844 [00:05<00:02, 106.30it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  70%|███████   | 593/844 [00:05<00:02, 105.69it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  72%|███████▏  | 604/844 [00:05<00:02, 106.07it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  73%|███████▎  | 615/844 [00:05<00:02, 105.69it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  74%|███████▍  | 626/844 [00:05<00:02, 106.25it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  75%|███████▌  | 637/844 [00:06<00:01, 106.08it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  77%|███████▋  | 648/844 [00:06<00:01, 106.24it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  78%|███████▊  | 659/844 [00:06<00:01, 106.52it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  79%|███████▉  | 670/844 [00:06<00:01, 106.54it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  81%|████████  | 681/844 [00:06<00:01, 106.52it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  82%|████████▏ | 692/844 [00:06<00:01, 106.60it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  83%|████████▎ | 703/844 [00:06<00:01, 106.81it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  85%|████████▍ | 714/844 [00:06<00:01, 106.92it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  86%|████████▌ | 725/844 [00:06<00:01, 106.58it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  87%|████████▋ | 736/844 [00:06<00:01, 105.86it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  89%|████████▊ | 747/844 [00:07<00:00, 105.14it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  90%|████████▉ | 758/844 [00:07<00:00, 105.52it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  91%|█████████ | 769/844 [00:07<00:00, 105.54it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  92%|█████████▏| 780/844 [00:07<00:00, 105.64it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  94%|█████████▎| 791/844 [00:07<00:00, 105.51it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  95%|█████████▌| 802/844 [00:07<00:00, 104.95it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  96%|█████████▋| 813/844 [00:07<00:00, 103.72it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  98%|█████████▊| 824/844 [00:07<00:00, 101.94it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
#  99%|█████████▉| 835/844 [00:07<00:00, 102.03it/s]/tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# /tmp/ipykernel_19/1267022848.py:6: RuntimeWarning: invalid value encountered in less
#   xyz[xyz<-1e17]=float('Nan');
# 100%|██████████| 844/844 [00:08<00:00, 104.92it/s]

# %%
data={
      "sequence":train_sequences['sequence'].to_list(),
      "xyz": all_xyz
}

# %%
train_index = train_sequences.index
print(f"Test size: {len(train_index)}")
# Out:
# Test size: 844

# %% [markdown]
# ## Step 4: Dataset Class

# %%
from torch.utils.data import Dataset, DataLoader
from ast import literal_eval

def get_ct(bp,s):
    ct_matrix=np.zeros((len(s),len(s)))
    for b in bp:
        ct_matrix[b[0]-1,b[1]-1]=1
    return ct_matrix

class RNA3D_Dataset(Dataset):
    def __init__(self,indices,data):
        self.indices  = indices
        self.data     = data
        self.tokens   = {nt:i for i,nt in enumerate('ACGU')}

    def __len__(self):
        return len(self.indices)
    
    def __getitem__(self, idx):
        idx      = self.indices[idx]
        sequence = [self.tokens[nt] for nt in (self.data['sequence'][idx]) if nt in self.tokens]
        sequence = np.array(sequence)
        sequence = torch.tensor(sequence)

        #get C1' xyz
        xyz      = self.data['xyz'][idx]
        xyz      = torch.tensor(np.array(xyz))


        if len(sequence)>config['max_len']:
            crop_start  = np.random.randint(len(sequence)-config['max_len'])
            crop_end    = crop_start+config['max_len']
            sequence    = sequence[crop_start:crop_end]
            xyz         = xyz[crop_start:crop_end]

        return {'sequence' : sequence, 'xyz' : xyz}

# %%
test_dataset=RNA3D_Dataset(train_index, data)
test_dataset[0]
# Out:
# {'sequence': tensor([2, 2, 2, 3, 2, 1, 3, 1, 0, 2, 3, 0, 1, 2, 0, 2, 0, 2, 2, 0, 0, 1, 1, 2,
#          1, 0, 1, 1, 1]),
#  'xyz': tensor([[ 13.7600, -25.9740,   0.1020],
#          [  9.3100, -29.6380,   2.6690],
#          [  5.5290, -27.8130,   5.8780],
#          [  2.6780, -24.9010,   9.7930],
#          [  1.8270, -20.1360,  11.7930],
#          [  2.0400, -14.9080,  11.7710],
#          [  1.1070, -11.5130,   7.5170],
#          [  2.9910,  -6.4060,   4.7830],
#          [  0.8960,  -1.1930,   7.6080],
#          [  0.2280,   2.6460,   9.1280],
#          [  4.3290,   2.7180,   4.8040],
#          [  5.1650,   4.7920,  -0.9140],
#          [  2.6100,   9.4950,  -2.3080],
#          [  1.1740,  13.8290,   0.2010],
#          [  1.5800,  20.1150,   3.7600],
#          [ -1.5750,  16.9280,   5.8970],
#          [ -6.0510,  14.7620,   5.2240],
#          [ -5.5540,  10.4150,   4.3090],
#          [ -3.1070,   6.4050,   2.1200],
#          [ -1.4100,   3.3350,  -2.6550],
#          [  1.8660,  -0.7160,  -4.3330],
#          [  3.6550,  -4.4440,  -2.4850],
#          [  5.3140,  -7.6560,   1.1300],
#          [  7.9310,  -9.5280,   5.7810],
#          [  8.7350, -12.6480,  10.0250],
#          [  9.1080, -17.2960,  13.0210],
#          [  8.8970, -22.6060,  14.3080],
#          [  9.6730, -28.3380,  13.2920],
#          [ 12.6410, -30.9070,   9.6450]])}

# %% [markdown]
# ## Step 5: Load model

# %%
import sys

sys.path.append("/kaggle/input/ribonanzanet2d-final")


from Network import *
import yaml



class Config:
    def __init__(self, **entries):
        self.__dict__.update(entries)
        self.entries=entries

    def print(self):
        print(self.entries)

def load_config_from_yaml(file_path):
    with open(file_path, 'r') as file:
        config = yaml.safe_load(file)
    return Config(**config)

class finetuned_RibonanzaNet(RibonanzaNet):
    def __init__(self, config, pretrained=False):
        config.dropout=0.2
        super(finetuned_RibonanzaNet, self).__init__(config)
        if pretrained:
            self.load_state_dict(torch.load("/kaggle/input/ribonanzanet-weights/RibonanzaNet.pt",map_location='cpu'))
        self.dropout=nn.Dropout(0.0)
        self.xyz_predictor=nn.Linear(256,3)

    def forward(self,src):
        sequence_features, pairwise_features=self.get_embeddings(src, torch.ones_like(src).long().to(src.device))

        xyz=self.xyz_predictor(sequence_features)

        return xyz

# %%
model=finetuned_RibonanzaNet(load_config_from_yaml("/kaggle/input/ribonanzanet2d-final/configs/pairwise.yaml"),pretrained=False).cuda()

model.load_state_dict(torch.load("/kaggle/input/ribonanzanet-3d-finetune/RibonanzaNet-3D.pt"))
# Out:
# constructing 9 ConvTransformerEncoderLayers
# /tmp/ipykernel_19/3506299211.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("/kaggle/input/ribonanzanet-3d-finetune/RibonanzaNet-3D.pt"))
# <All keys matched successfully>

# %%
test_dataset[0]['sequence'].shape
# Out:
# torch.Size([29])

# %% [markdown]
# ## Step 6: Model Inference

# %%
from tqdm import tqdm

model.eval()
preds=[]
for i in tqdm(range(len(test_dataset))):
    src=test_dataset[i]['sequence'].long()
    src=src.unsqueeze(0).cuda()

    model.train()

    tmp=[]
    for i in range(4):
        with torch.no_grad():
            xyz=model(src).squeeze()
        tmp.append(xyz.cpu().numpy())

    model.eval()
    with torch.no_grad():
        xyz=model(src).squeeze()
    tmp.append(xyz.cpu().numpy())

    tmp=np.stack(tmp,0)
    #exit()
    preds.append(tmp)
# Out:
#   0%|          | 0/844 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# 100%|██████████| 844/844 [04:01<00:00,  3.50it/s]

# %%
import plotly.graph_objects as go
import numpy as np

# Example: Generate an Nx3 matrix

xyz = preds[2][1]  # Replace this with your actual Nx3 data
N = len(xyz)

# Extract columns
x, y, z = xyz[:, 0], xyz[:, 1], xyz[:, 2]

# Create the 3D scatter plot
fig = go.Figure(data=[go.Scatter3d(
    x=x, y=y, z=z,
    mode='markers',
    marker=dict(
        size=5,
        color=z,  # Coloring based on z-value
        colorscale='Viridis',  # Choose a colorscale
        opacity=0.8
    )
)])

# Customize layout
fig.update_layout(
    scene=dict(
        xaxis_title="X",
        yaxis_title="Y",
        zaxis_title="Z"
    ),
    title="3D Scatter Plot"
)

# Show figure
fig.show(renderer='iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_14.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
tmp.shape
# Out:
# (5, 86, 3)

# %%
preds[0]
# Out:
# array([[[ 7.33692312e+00,  1.67382355e+01,  4.83677387e+00],
#         [ 9.51375961e+00,  1.51120358e+01,  4.14232016e+00],
#         [ 1.23284683e+01,  1.06005154e+01,  3.29774737e+00],
#         [ 1.21508303e+01,  4.39496422e+00,  2.79672027e+00],
#         [ 1.11909971e+01,  1.31413722e+00,  3.45936567e-01],
#         [ 7.06607628e+00, -8.35438371e-01,  5.89075804e-01],
#         [ 2.60309315e+00, -4.58466816e+00, -1.30309594e+00],
#         [ 1.52563319e-01, -3.48567247e+00, -2.88089252e+00],
#         [-5.22892714e+00, -5.82414484e+00, -4.61940336e+00],
#         [-4.80920506e+00, -8.44968605e+00, -6.02586889e+00],
#         [-8.97599125e+00, -3.93101645e+00, -5.30110788e+00],
#         [-1.32758398e+01, -2.49770951e+00, -7.48438883e+00],
#         [-1.55210123e+01, -6.79638743e-01, -1.38572454e+01],
#         [-1.70961227e+01, -4.73178291e+00, -1.34341812e+01],
#         [-2.06844826e+01, -9.03652668e+00, -1.75919456e+01],
#         [-1.73351440e+01, -1.14871922e+01, -1.52317257e+01],
#         [-1.26567125e+01, -1.37759199e+01, -1.82503204e+01],
#         [-1.00545692e+01, -9.17628670e+00, -1.61156006e+01],
#         [-7.81005239e+00, -6.31813002e+00, -1.34855661e+01],
#         [-8.40843964e+00,  1.98316723e-02, -1.21739855e+01],
#         [-9.09068203e+00,  2.51599216e+00, -9.27204990e+00],
#         [-5.26085138e+00,  4.11094761e+00, -5.39399242e+00],
#         [-5.21899796e+00,  4.34198856e+00, -1.77609515e+00],
#         [-2.44387245e+00,  2.65414000e+00,  1.62593532e+00],
#         [ 1.32643402e+00,  9.50534463e-01,  5.19031715e+00],
#         [ 5.81604958e+00,  2.42342329e+00,  7.69529963e+00],
#         [ 1.06661501e+01,  4.88806963e+00,  8.70495319e+00],
#         [ 1.27776642e+01,  8.00760746e+00,  8.60729027e+00],
#         [ 1.45981064e+01,  1.34830465e+01,  1.11430540e+01]],
#
#        [[ 6.32320642e+00,  1.70318680e+01,  6.87719393e+00],
#         [ 8.50827694e+00,  1.45347538e+01,  4.99857616e+00],
#         [ 1.30553980e+01,  1.12728739e+01,  2.62948632e+00],
#         [ 1.26777039e+01,  7.87184238e+00,  6.35009825e-01],
#         [ 1.06496191e+01,  7.25468814e-01,  9.99373972e-01],
#         [ 6.68039417e+00, -1.35177386e+00,  1.32539248e+00],
#         [ 1.96953189e+00, -2.18106985e+00, -1.47232890e+00],
#         [-1.67140388e+00, -2.26982927e+00, -3.71121764e+00],
#         [-4.50849676e+00, -7.13602304e+00, -5.35590458e+00],
#         [-6.66747046e+00, -7.86123276e+00, -4.77462912e+00],
#         [-1.02957640e+01, -3.49800396e+00, -4.99210453e+00],
#         [-1.34560308e+01, -1.09267211e+00, -8.63831043e+00],
#         [-1.69560490e+01, -1.96400329e-01, -1.10553827e+01],
#         [-1.66478062e+01, -3.87839794e+00, -1.42359676e+01],
#         [-2.00952282e+01, -1.07470770e+01, -1.69440689e+01],
#         [-1.39634600e+01, -1.21586895e+01, -1.61910629e+01],
#         [-9.24057961e+00, -1.25310736e+01, -1.92110100e+01],
#         [-8.75919819e+00, -8.09375668e+00, -1.64664249e+01],
#         [-6.42860985e+00, -3.28367090e+00, -1.40626106e+01],
#         [-9.23635769e+00, -9.83335227e-02, -1.21586637e+01],
#         [-1.01661701e+01,  4.25660467e+00, -8.55961037e+00],
#         [-7.33878946e+00,  5.27499247e+00, -5.40520716e+00],
#         [-5.74205542e+00,  4.25468111e+00, -4.64453518e-01],
#         [-3.04651546e+00,  3.46728325e+00,  3.69960666e+00],
#         [ 7.43221164e-01,  1.88125825e+00,  6.47886038e+00],
#         [ 6.04251432e+00,  2.03067160e+00,  7.86435556e+00],
#         [ 9.91745186e+00,  2.88515544e+00,  8.83888149e+00],
#         [ 1.21223593e+01,  7.66181326e+00,  1.12062941e+01],
#         [ 1.30822210e+01,  1.34624805e+01,  1.07287302e+01]],
#
#        [[ 6.95762491e+00,  1.94339333e+01,  6.66450834e+00],
#         [ 9.56144905e+00,  1.46719074e+01,  3.88947511e+00],
#         [ 1.08877373e+01,  1.21568851e+01,  3.99510026e+00],
#         [ 1.38644838e+01,  6.87868261e+00,  2.77290702e+00],
#         [ 1.16720524e+01,  9.40869033e-01,  1.74779868e+00],
#         [ 7.21640921e+00, -1.23676729e+00,  7.94875696e-02],
#         [ 3.88218975e+00, -7.63478398e-01, -1.55562997e+00],
#         [-1.97004259e+00, -6.24462128e-01, -3.15876031e+00],
#         [-3.42597818e+00, -4.21915102e+00, -4.47785711e+00],
#         [-5.55598402e+00, -7.54546452e+00, -5.42888355e+00],
#         [-1.11093006e+01, -2.47388268e+00, -4.78364897e+00],
#         [-1.34821768e+01,  3.65439504e-02, -7.90153313e+00],
#         [-1.50472918e+01,  1.86896816e-01, -1.36378660e+01],
#         [-1.58107204e+01, -5.66946173e+00, -1.45595140e+01],
#         [-1.77683239e+01, -1.21904907e+01, -1.74763355e+01],
#         [-1.28950920e+01, -1.34581032e+01, -1.71369133e+01],
#         [-9.66638184e+00, -1.22644062e+01, -1.78806286e+01],
#         [-8.41717720e+00, -7.07797527e+00, -1.68477821e+01],
#         [-6.67403269e+00, -3.33516335e+00, -1.42894964e+01],
#         [-9.28076458e+00,  2.14572835e+00, -1.25338202e+01],
#         [-7.30844259e+00,  3.51481628e+00, -7.37556791e+00],
#         [-6.63994312e+00,  4.47720385e+00, -4.52236032e+00],
#         [-4.73937798e+00,  5.60100937e+00,  2.94187397e-01],
#         [-1.10913193e+00,  2.69811678e+00,  4.15074396e+00],
#         [ 2.51305676e+00,  8.23619068e-01,  5.29832792e+00],
#         [ 9.20181656e+00,  2.67117596e+00,  6.63435030e+00],
#         [ 1.14276686e+01,  6.21891022e+00,  8.04405117e+00],
#         [ 1.33872261e+01,  9.25578880e+00,  9.99332523e+00],
#         [ 1.55499010e+01,  1.37093430e+01,  1.13410120e+01]],
#
#        [[ 5.92989349e+00,  1.73756714e+01,  7.38026285e+00],
#         [ 9.78312397e+00,  1.36721048e+01,  8.11371899e+00],
#         [ 1.16870413e+01,  9.42023087e+00,  4.59219074e+00],
#         [ 1.00561533e+01,  4.36699057e+00,  3.33333087e+00],
#         [ 8.59668350e+00,  1.10515332e+00,  9.75656331e-01],
#         [ 5.89662027e+00, -7.60085732e-02, -5.45866549e-01],
#         [ 2.18097925e+00,  5.99408507e-01, -2.02823997e+00],
#         [-1.85882223e+00, -2.44153285e+00, -3.23713470e+00],
#         [-4.24865437e+00, -3.53153849e+00, -4.24033689e+00],
#         [-8.80419159e+00, -8.39500332e+00, -5.32667971e+00],
#         [-1.05938635e+01, -2.90155840e+00, -6.75419950e+00],
#         [-1.38001242e+01, -5.73437512e-01, -9.21984386e+00],
#         [-1.50889025e+01, -1.22506487e+00, -1.52841415e+01],
#         [-1.65185699e+01, -6.21198702e+00, -1.60614853e+01],
#         [-1.94670124e+01, -1.43197260e+01, -1.54955263e+01],
#         [-1.52335501e+01, -1.36343794e+01, -1.44015303e+01],
#         [-8.92449665e+00, -1.38860044e+01, -1.71667595e+01],
#         [-8.02122974e+00, -1.00075836e+01, -1.58462725e+01],
#         [-5.55910444e+00, -5.33047915e+00, -1.38086243e+01],
#         [-8.28995609e+00, -1.35023579e-01, -1.20263700e+01],
#         [-7.41685724e+00,  4.04612589e+00, -9.66788578e+00],
#         [-5.95376635e+00,  5.93297529e+00, -6.24783850e+00],
#         [-5.66126871e+00,  5.86274719e+00, -1.44231892e+00],
#         [-4.85168028e+00,  3.75465012e+00,  2.85165739e+00],
#         [-1.39101446e+00,  2.56030416e+00,  5.67924023e+00],
#         [ 3.45907784e+00,  1.21600258e+00,  8.58737278e+00],
#         [ 9.15014267e+00,  3.88231301e+00,  9.71773911e+00],
#         [ 1.27292547e+01,  5.90340805e+00,  1.09799337e+01],
#         [ 1.44862366e+01,  1.06566839e+01,  9.73333645e+00]],
#
#        [[ 6.37430477e+00,  1.90932655e+01,  9.94710255e+00],
#         [ 1.13713236e+01,  1.64232693e+01,  9.64882660e+00],
#         [ 1.40477896e+01,  1.20286865e+01,  7.88182735e+00],
#         [ 1.34853001e+01,  7.11709023e+00,  6.59089899e+00],
#         [ 1.17484655e+01,  2.71339846e+00,  4.36858940e+00],
#         [ 7.87137175e+00,  2.71941781e-01,  1.25145769e+00],
#         [ 3.87257004e+00,  7.32367158e-01, -2.77123189e+00],
#         [-5.30669808e-01, -4.75169361e-01, -3.93840575e+00],
#         [-3.28241777e+00, -5.34018564e+00, -6.47052765e+00],
#         [-5.78728914e+00, -8.74733543e+00, -6.61821795e+00],
#         [-1.02498274e+01, -4.76993656e+00, -5.97761679e+00],
#         [-1.52172956e+01, -1.78815842e+00, -9.57772350e+00],
#         [-1.90434475e+01, -4.20533562e+00, -1.35338297e+01],
#         [-2.04263706e+01, -9.22631645e+00, -1.53927832e+01],
#         [-2.23839302e+01, -1.63944550e+01, -1.67899609e+01],
#         [-1.76900501e+01, -1.63560715e+01, -1.52127724e+01],
#         [-1.56047068e+01, -1.62539558e+01, -1.72307262e+01],
#         [-1.27027836e+01, -1.26200829e+01, -1.61457062e+01],
#         [-1.01798182e+01, -8.35691071e+00, -1.52425652e+01],
#         [-1.02021580e+01, -1.71780908e+00, -1.45971966e+01],
#         [-8.71385670e+00,  3.31023574e+00, -1.26576929e+01],
#         [-6.34590292e+00,  4.61760664e+00, -8.53227806e+00],
#         [-5.00172997e+00,  4.27348614e+00, -3.94237494e+00],
#         [-2.88816690e+00,  3.02062130e+00,  8.49653006e-01],
#         [ 2.54294366e-01,  2.26442051e+00,  4.79222584e+00],
#         [ 5.20523119e+00,  3.05868411e+00,  9.38372421e+00],
#         [ 9.54910183e+00,  5.57922459e+00,  1.25681000e+01],
#         [ 1.15661583e+01,  9.35337353e+00,  1.52859001e+01],
#         [ 1.41188116e+01,  1.25047512e+01,  1.59582090e+01]]],
#       dtype=float32)

# %%
preds[7][0].shape
# Out:
# (32, 3)

# %%
length = 0
length_greater_than_384 = 0
length_greater_than_384_cnt = 0

for idx, row in train_sequences.iterrows():
    current_length = len(row["sequence"])
    length = length + current_length

    if current_length > 384:
        length_greater_than_384 += current_length-384
        length_greater_than_384_cnt += 1

length, length_greater_than_384, length-length_greater_than_384, length_greater_than_384_cnt
# Out:
# (137095, 72651, 64444, 46)

# %%
ID=[]
resname=[]
resid=[]
x=[]
y=[]
z=[]

data=[]

for i in tqdm(range(len(train_sequences))):
    try:
        for j in range(len(train_sequences.loc[i,'sequence'])):
            row=[train_sequences.loc[i,'target_id']+f"_{j+1}", 
                 train_sequences.loc[i,'sequence'][j],
                 j+1]
    
            for k in range(5):
                for kk in range(3):
                    row.append(preds[i][k][j][kk])
            data.append(row)
    except Exception as e:
        print(e)

columns=['ID','resname','resid']
for i in range(1,6):
    columns+=[f"x_{i}"]
    columns+=[f"y_{i}"]
    columns+=[f"z_{i}"]


submission=pd.DataFrame(data,columns=columns)


submission
submission.to_csv('submission.csv',index=False)
# Out:
#  36%|███▌      | 300/844 [00:00<00:00, 1157.09it/s]
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
#  50%|████▉     | 421/844 [00:00<00:00, 933.27it/s]
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
#  62%|██████▏   | 520/844 [00:00<00:00, 493.42it/s]
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
#  77%|███████▋  | 653/844 [00:01<00:00, 463.68it/s]
# index 384 is out of bounds for axis 0 with size 384
# index 101 is out of bounds for axis 0 with size 101
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 47 is out of bounds for axis 0 with size 47
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 80 is out of bounds for axis 0 with size 80
#  90%|█████████ | 762/844 [00:01<00:00, 454.41it/s]
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# index 384 is out of bounds for axis 0 with size 384
# 100%|██████████| 844/844 [00:01<00:00, 546.03it/s]
# index 145 is out of bounds for axis 0 with size 145
# index 384 is out of bounds for axis 0 with size 384

# %%
submission
# Out:
#               ID resname  resid        x_1        y_1        z_1        x_2  \
# 0       1SCL_A_1       G      1   7.336923  16.738235   4.836774   6.323206
# 1       1SCL_A_2       G      2   9.513760  15.112036   4.142320   8.508277
# 2       1SCL_A_3       G      3  12.328468  10.600515   3.297747  13.055398
# 3       1SCL_A_4       U      4  12.150830   4.394964   2.796720  12.677704
# 4       1SCL_A_5       G      5  11.190997   1.314137   0.345937  10.649619
# ...          ...     ...    ...        ...        ...        ...        ...
# 64433  8Z1F_T_82       U     82   0.026509  31.825565  12.412617   5.286232
# 64434  8Z1F_T_83       C     83  -4.547946  28.844946   9.258884   1.353285
# 64435  8Z1F_T_84       A     84   3.868995  38.780537  22.346367  10.735499
# 64436  8Z1F_T_85       U     85   0.583747  35.567463  16.640093   8.062943
# 64437  8Z1F_T_86       A     86   5.574851  37.949120  19.723589  10.488847
#
#              y_2        z_2        x_3        y_3        z_3        x_4  \
# 0      17.031868   6.877194   6.957625  19.433933   6.664508   5.929893
# 1      14.534754   4.998576   9.561449  14.671907   3.889475   9.783124
# 2      11.272874   2.629486  10.887737  12.156885   3.995100  11.687041
# 3       7.871842   0.635010  13.864484   6.878683   2.772907  10.056153
# 4       0.725469   0.999374  11.672052   0.940869   1.747799   8.596684
# ...          ...        ...        ...        ...        ...        ...
# 64433  41.681656  30.244347  10.015234  39.762413  33.105328  11.494699
# 64434  38.043369  29.382427   4.806351  37.216377  24.306120  12.338634
# 64435  40.702148  30.869923  10.250741  40.913345  28.519682  10.295520
# 64436  39.324131  28.094059   9.664435  38.202061  27.783079   6.892276
# 64437  40.517082  22.736633  17.223391  41.957535  27.660862  12.542595
#
#              y_4        z_4        x_5        y_5        z_5
# 0      17.375671   7.380263   6.374305  19.093266   9.947103
# 1      13.672105   8.113719  11.371324  16.423269   9.648827
# 2       9.420231   4.592191  14.047790  12.028687   7.881827
# 3       4.366991   3.333331  13.485300   7.117090   6.590899
# 4       1.105153   0.975656  11.748466   2.713398   4.368589
# ...          ...        ...        ...        ...        ...
# 64433  37.702106  20.402130   1.482342  43.018700  26.166098
# 64434  42.154572  29.318447   1.607505  43.395157  26.519369
# 64435  37.302853  27.617889   1.085683  41.920780  23.554651
# 64436  36.668190  18.942503   2.878160  41.831444  21.701105
# 64437  34.400261  27.520786   2.985748  43.055229  24.101803
#
# [64438 rows x 18 columns]

# %%
submission["flag"] = False

for idx, row in submission.iterrows():
    if row["x_1"] == 0.0 and row["y_1"] == 0.0 and row["z_1"] == 0.0:
        submission.loc[idx, "flag"] = True

# %%
train_labels.rename(columns={"x_1":"x_1_true","y_1":"y_1_true","z_1":"z_1_true" }, inplace=True)

# %%
merged_df = submission.merge(train_labels[["ID", "x_1_true", "y_1_true", "z_1_true"]], on=["ID"])

# %%
merged_df
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning:
#
# invalid value encountered in greater
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning:
#
# invalid value encountered in greater
#               ID resname  resid        x_1        y_1        z_1        x_2  \
# 0       1SCL_A_1       G      1   7.336923  16.738235   4.836774   6.323206
# 1       1SCL_A_2       G      2   9.513760  15.112036   4.142320   8.508277
# 2       1SCL_A_3       G      3  12.328468  10.600515   3.297747  13.055398
# 3       1SCL_A_4       U      4  12.150830   4.394964   2.796720  12.677704
# 4       1SCL_A_5       G      5  11.190997   1.314137   0.345937  10.649619
# ...          ...     ...    ...        ...        ...        ...        ...
# 64433  8Z1F_T_82       U     82   0.026509  31.825565  12.412617   5.286232
# 64434  8Z1F_T_83       C     83  -4.547946  28.844946   9.258884   1.353285
# 64435  8Z1F_T_84       A     84   3.868995  38.780537  22.346367  10.735499
# 64436  8Z1F_T_85       U     85   0.583747  35.567463  16.640093   8.062943
# 64437  8Z1F_T_86       A     86   5.574851  37.949120  19.723589  10.488847
#
#              y_2        z_2        x_3  ...        x_4        y_4        z_4  \
# 0      17.031868   6.877194   6.957625  ...   5.929893  17.375671   7.380263
# 1      14.534754   4.998576   9.561449  ...   9.783124  13.672105   8.113719
# 2      11.272874   2.629486  10.887737  ...  11.687041   9.420231   4.592191
# 3       7.871842   0.635010  13.864484  ...  10.056153   4.366991   3.333331
# 4       0.725469   0.999374  11.672052  ...   8.596684   1.105153   0.975656
# ...          ...        ...        ...  ...        ...        ...        ...
# 64433  41.681656  30.244347  10.015234  ...  11.494699  37.702106  20.402130
# 64434  38.043369  29.382427   4.806351  ...  12.338634  42.154572  29.318447
# 64435  40.702148  30.869923  10.250741  ...  10.295520  37.302853  27.617889
# 64436  39.324131  28.094059   9.664435  ...   6.892276  36.668190  18.942503
# 64437  40.517082  22.736633  17.223391  ...  12.542595  34.400261  27.520786
#
#              x_5        y_5        z_5   flag  x_1_true   y_1_true  z_1_true
# 0       6.374305  19.093266   9.947103  False    13.760 -25.974001     0.102
# 1      11.371324  16.423269   9.648827  False     9.310 -29.638000     2.669
# 2      14.047790  12.028687   7.881827  False     5.529 -27.813000     5.878
# 3      13.485300   7.117090   6.590899  False     2.678 -24.900999     9.793
# 4      11.748466   2.713398   4.368589  False     1.827 -20.136000    11.793
# ...          ...        ...        ...    ...       ...        ...       ...
# 64433   1.482342  43.018700  26.166098  False       NaN        NaN       NaN
# 64434   1.607505  43.395157  26.519369  False       NaN        NaN       NaN
# 64435   1.085683  41.920780  23.554651  False       NaN        NaN       NaN
# 64436   2.878160  41.831444  21.701105  False       NaN        NaN       NaN
# 64437   2.985748  43.055229  24.101803  False       NaN        NaN       NaN
#
# [64438 rows x 22 columns]

# %%
final_df = merged_df[~merged_df["x_1_true"].isna()]

# %%
final_df
# Out:
#               ID resname  resid        x_1        y_1        z_1        x_2  \
# 0       1SCL_A_1       G      1   7.336923  16.738235   4.836774   6.323206
# 1       1SCL_A_2       G      2   9.513760  15.112036   4.142320   8.508277
# 2       1SCL_A_3       G      3  12.328468  10.600515   3.297747  13.055398
# 3       1SCL_A_4       U      4  12.150830   4.394964   2.796720  12.677704
# 4       1SCL_A_5       G      5  11.190997   1.314137   0.345937  10.649619
# ...          ...     ...    ...        ...        ...        ...        ...
# 64413  8Z1F_T_62       U     62   9.595567   7.404656  13.769807   9.993127
# 64414  8Z1F_T_63       A     63  12.535778   8.934927  14.085622  11.642522
# 64415  8Z1F_T_64       C     64  16.335852   9.249647  12.175087  16.647243
# 64416  8Z1F_T_65       C     65  17.428249  10.387369  11.426862  20.692896
# 64417  8Z1F_T_66       A     66  18.641239  19.065002  18.906132  21.175066
#
#              y_2        z_2        x_3  ...        x_4        y_4        z_4  \
# 0      17.031868   6.877194   6.957625  ...   5.929893  17.375671   7.380263
# 1      14.534754   4.998576   9.561449  ...   9.783124  13.672105   8.113719
# 2      11.272874   2.629486  10.887737  ...  11.687041   9.420231   4.592191
# 3       7.871842   0.635010  13.864484  ...  10.056153   4.366991   3.333331
# 4       0.725469   0.999374  11.672052  ...   8.596684   1.105153   0.975656
# ...          ...        ...        ...  ...        ...        ...        ...
# 64413   4.528863  10.242212   9.730031  ...   5.358267   2.095401  11.791045
# 64414   6.080662  12.158369  11.145070  ...   9.600068  -2.015361  14.205014
# 64415   8.480448  10.581591  13.585906  ...  11.012373   1.640385  14.024781
# 64416  12.840609  11.874450  17.572828  ...  16.521351   7.169189  12.243554
# 64417  11.177689  14.065049  19.309038  ...  14.953912   9.583868  18.945446
#
#              x_5        y_5        z_5   flag    x_1_true    y_1_true  \
# 0       6.374305  19.093266   9.947103  False   13.760000  -25.974001
# 1      11.371324  16.423269   9.648827  False    9.310000  -29.638000
# 2      14.047790  12.028687   7.881827  False    5.529000  -27.813000
# 3      13.485300   7.117090   6.590899  False    2.678000  -24.900999
# 4      11.748466   2.713398   4.368589  False    1.827000  -20.136000
# ...          ...        ...        ...    ...         ...         ...
# 64413  11.311334   6.068553  10.731156  False  112.516998  117.880997
# 64414  15.480549   6.695855   9.949566  False  115.292999  116.571999
# 64415  18.642389   8.138820   9.252250  False  115.857002  114.595001
# 64416  21.481298  12.728823   8.446400  False  113.816002  113.236000
# 64417  24.468552  14.041500  12.847883  False  118.279999  113.883003
#
#          z_1_true
# 0        0.102000
# 1        2.669000
# 2        5.878000
# 3        9.793000
# 4       11.793000
# ...           ...
# 64413  119.245003
# 64414  114.827003
# 64415  109.509003
# 64416  104.339996
# 64417   98.071999
#
# [59508 rows x 22 columns]

# %%
final_df.to_csv("ribonanzanet1_public_oof.csv")
